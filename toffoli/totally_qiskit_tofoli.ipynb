# %%
from qiskit import transpile
from qiskit import QuantumCircuit, QuantumRegister

# Init Circuit
qc = QuantumCircuit()
q_con = QuantumRegister(14, 'q_c')
q_t = QuantumRegister(1, 'q_t')
q_ancilla = QuantumRegister(5, 'q_a')
qc.add_register(q_con)
qc.add_register(q_t)
qc.add_register(q_ancilla)

qc.mcx(q_con,q_t,ancilla_qubits=q_ancilla,mode="recursion")

print("total depth is: " , qc.decompose().depth())
qc.decompose().draw()
# Out:
# total depth is:  27
#                                                                               »
#  q_c_0: ──■─────────■───────────────────────────────────────■─────────────────»
#           │         │                                       │                 »
#  q_c_1: ──■─────────■───────────────────────────────────────■─────────────────»
#           │         │                                       │                 »
#  q_c_2: ──■─────────■───────────────────────────────────────■─────────────────»
#           │         │                                       │                 »
#  q_c_3: ──■─────────■───────────────────────────────────────■─────────────────»
#           │         │                                       │                 »
#  q_c_4: ──┼────■────┼────■──────────────────────────────────┼─────────────────»
#           │    │    │    │                                  │                 »
#  q_c_5: ──┼────■────┼────■──────────────────────────────────┼─────────────────»
#           │    │    │    │  ┌───┐                    ┌───┐  │                 »
#  q_c_6: ──┼────■────┼────■──┤ X ├───────■─────────■──┤ X ├──┼────■─────────■──»
#         ┌─┴─┐  │  ┌─┴─┐  │  └─┬─┘       │         │  └─┬─┘┌─┴─┐  │         │  »
#  q_c_7: ┤ X ├──■──┤ X ├──■────■─────────┼─────────┼────■──┤ X ├──┼─────────┼──»
#         └───┘  │  └───┘  │    │         │         │    │  └───┘  │         │  »
#  q_c_8: ───────┼─────────┼────■─────────┼─────────┼────■─────────┼─────────┼──»
#                │         │    │         │         │    │         │         │  »
#  q_c_9: ───────┼─────────┼────■─────────┼─────────┼────■─────────┼─────────┼──»
#                │         │    │  ┌───┐  │  ┌───┐  │    │  ┌───┐  │  ┌───┐  │  »
# q_c_10: ───────┼─────────┼────■──┤ X ├──■──┤ X ├──■────■──┤ X ├──■──┤ X ├──■──»
#                │         │       └─┬─┘  │  └─┬─┘  │       └─┬─┘  │  └─┬─┘  │  »
# q_c_11: ───────┼─────────┼─────────■────┼────■────┼─────────■────┼────■────┼──»
#                │         │         │    │    │    │         │    │    │    │  »
# q_c_12: ───────┼─────────┼─────────■────┼────■────┼─────────■────┼────■────┼──»
#                │         │         │    │    │    │         │    │    │    │  »
# q_c_13: ───────┼─────────┼─────────■────┼────■────┼─────────■────┼────■────┼──»
#                │         │            ┌─┴─┐     ┌─┴─┐          ┌─┴─┐     ┌─┴─┐»
#  q_t_0: ───────┼─────────┼────────────┤ X ├─────┤ X ├──────────┤ X ├─────┤ X ├»
#              ┌─┴─┐     ┌─┴─┐          └─┬─┘     └─┬─┘          └─┬─┘     └─┬─┘»
#  q_a_0: ─────┤ X ├─────┤ X ├────────────■─────────■──────────────■─────────■──»
#              └───┘     └───┘                                                  »
#  q_a_1: ──────────────────────────────────────────────────────────────────────»
#                                                                               »
#  q_a_2: ──────────────────────────────────────────────────────────────────────»
#                                                                               »
#  q_a_3: ──────────────────────────────────────────────────────────────────────»
#                                                                               »
#  q_a_4: ──────────────────────────────────────────────────────────────────────»
#                                                                               »
# «
# « q_c_0: ───────■─────────────────────────────────────────────────────────
# «               │
# « q_c_1: ───────■─────────────────────────────────────────────────────────
# «               │
# « q_c_2: ───────■─────────────────────────────────────────────────────────
# «               │
# « q_c_3: ───────■─────────────────────────────────────────────────────────
# «               │
# « q_c_4: ──■────┼────■────────────────────────────────────────────────────
# «          │    │    │
# « q_c_5: ──■────┼────■────────────────────────────────────────────────────
# «          │    │    │  ┌───┐                    ┌───┐
# « q_c_6: ──■────┼────■──┤ X ├───────■─────────■──┤ X ├───────■─────────■──
# «          │  ┌─┴─┐  │  └─┬─┘       │         │  └─┬─┘       │         │
# « q_c_7: ──■──┤ X ├──■────■─────────┼─────────┼────■─────────┼─────────┼──
# «          │  └───┘  │    │         │         │    │         │         │
# « q_c_8: ──┼─────────┼────■─────────┼─────────┼────■─────────┼─────────┼──
# «          │         │    │         │         │    │         │         │
# « q_c_9: ──┼─────────┼────■─────────┼─────────┼────■─────────┼─────────┼──
# «          │         │    │  ┌───┐  │  ┌───┐  │    │  ┌───┐  │  ┌───┐  │
# «q_c_10: ──┼─────────┼────■──┤ X ├──■──┤ X ├──■────■──┤ X ├──■──┤ X ├──■──
# «          │         │       └─┬─┘  │  └─┬─┘  │       └─┬─┘  │  └─┬─┘  │
# «q_c_11: ──┼─────────┼─────────■────┼────■────┼─────────■────┼────■────┼──
# «          │         │         │    │    │    │         │    │    │    │
# «q_c_12: ──┼─────────┼─────────■────┼────■────┼─────────■────┼────■────┼──
# «          │         │         │    │    │    │         │    │    │    │
# «q_c_13: ──┼─────────┼─────────■────┼────■────┼─────────■────┼────■────┼──
# «          │         │            ┌─┴─┐     ┌─┴─┐          ┌─┴─┐     ┌─┴─┐
# « q_t_0: ──┼─────────┼────────────┤ X ├─────┤ X ├──────────┤ X ├─────┤ X ├
# «        ┌─┴─┐     ┌─┴─┐          └─┬─┘     └─┬─┘          └─┬─┘     └─┬─┘
# « q_a_0: ┤ X ├─────┤ X ├────────────■─────────■──────────────■─────────■──
# «        └───┘     └───┘
# « q_a_1: ─────────────────────────────────────────────────────────────────
# «
# « q_a_2: ─────────────────────────────────────────────────────────────────
# «
# « q_a_3: ─────────────────────────────────────────────────────────────────
# «
# « q_a_4: ─────────────────────────────────────────────────────────────────
# «
